# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, BaggingRegressor
from nltk.stem.snowball import SnowballStemmer
import os

# %%
df_train = pd.read_csv('train.csv', encoding = "ISO-8859-1")
df_test = pd.read_csv('test.csv', encoding = "ISO-8859-1")
df_desc = pd.read_csv('product_descriptions.csv')

# %%
df_all=pd.concat([df_train.assign(is_train=1),df_test.assign(is_train=0)],axis=0,ignore_index=True)

# %%
df_all = pd.merge(df_all, df_desc, how='left', on='product_uid')

# %%
df_all
# Out:
#             id  product_uid  \
# 0            2       100001
# 1            3       100001
# 2            9       100002
# 3           16       100005
# 4           17       100005
# ...        ...          ...
# 240755  240756       224424
# 240756  240757       224425
# 240757  240758       224426
# 240758  240759       224427
# 240759  240760       224428
#
#                                             product_title  \
# 0                       Simpson Strong-Tie 12-Gauge Angle
# 1                       Simpson Strong-Tie 12-Gauge Angle
# 2       BEHR Premium Textured DeckOver 1-gal. #SC-141 ...
# 3       Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# 4       Delta Vero 1-Handle Shower Only Faucet Trim Ki...
# ...                                                   ...
# 240755  stufurhome Norma 24 in. W x 16 in. D x 34 in. ...
# 240756  Home Decorators Collection 49 in. D Alessandro...
# 240757  Simpson Strong-Tie HB 3-1/2 x 14 in. Top Flang...
# 240758  1/4 in. -20 tpi x 1-1/2 in. Stainless Steel Bu...
# 240759                      Bosch 4 in. Bi-Metal Hole Saw
#
#                      search_term  relevance  is_train  \
# 0                  angle bracket       3.00         1
# 1                      l bracket       2.50         1
# 2                      deck over       3.00         1
# 3               rain shower head       2.33         1
# 4             shower only faucet       2.67         1
# ...                          ...        ...       ...
# 240755  24 whtie storage cabinet        NaN         0
# 240756         adirondeck cusion        NaN         0
# 240757                        hb        NaN         0
# 240758               hex sockets        NaN         0
# 240759           4 inch hole saw        NaN         0
#
#                                       product_description
# 0       Not only do angles make joints stronger, they ...
# 1       Not only do angles make joints stronger, they ...
# 2       BEHR Premium Textured DECKOVER is an innovativ...
# 3       Update your bathroom with the Delta Vero Singl...
# 4       Update your bathroom with the Delta Vero Singl...
# ...                                                   ...
# 240755  Create a neat yet stylish storage space for or...
# 240756  Our Bullnose Adirondack Chair Cushions fit Adi...
# 240757  Joist hangers are designed to provide support ...
# 240758  These socket cap screws are ideal for applicat...
# 240759  The Bosch quick change bi-metal hole saws feat...
#
# [240760 rows x 7 columns]

# %%
stemmer = SnowballStemmer('english')
#把每一列中的每一条产品说明中的英文句子，小写lower() -> 分割split() -> 提取词干stemmer.stem -> 整合join
def str_stemmer(s):
    return " ".join([stemmer.stem(word) for word in s.lower().split()])
#计算"关键词次数" ： 统计两个字符串中的相同单词的个数
#python find()方法：http://www.runoob.com/python/att-string-find.html
def str_common_word(str1, str2):
    return sum(int(str2.find(word)>=0) for word in str1.split())

# %%
# %time df_all['search_term_transform'] = df_all['search_term'].map(lambda x:transform(x))
# %time df_all['product_title_transform'] = df_all['product_title'].map(lambda x:transform(x))
# %time df_all['pro_des_trans'] = df_all['product_description'].map(lambda x:transform(x))
# Out:
# Wall time: 5.04 s
# Wall time: 10.8 s
# Wall time: 1min 13s

# %%
# %time df_all['search_term'] = df_all['search_term_transform'].map(lambda x: str_stemmer(x))
# %time df_all['product_title'] = df_all['product_title_transform'].map(lambda x: str_stemmer(x))
# %time df_all['product_description'] = df_all['pro_des_trans'].map(lambda x: str_stemmer(x))
# Out:
# Wall time: 7.8 s
# Wall time: 25.3 s
# Wall time: 4min 37s

# %%
df_all
# Out:
#             id  product_uid  \
# 0            2       100001
# 1            3       100001
# 2            9       100002
# 3           16       100005
# 4           17       100005
# ...        ...          ...
# 240755  240756       224424
# 240756  240757       224425
# 240757  240758       224426
# 240758  240759       224427
# 240759  240760       224428
#
#                                             product_title  \
# 0                      simpson strong - tie 12- gaug angl
# 1                      simpson strong - tie 12- gaug angl
# 2       behr premium textur deck 1- gal . sc -141 tugb...
# 3       delta vero 1- handl shower faucet trim kit chr...
# 4       delta vero 1- handl shower faucet trim kit chr...
# ...                                                   ...
# 240755  stufurhom norma 24 . w x 16 . x 34 . h linen s...
# 240756  home decor collect 49 . alessandro spiceberri ...
# 240757  simpson strong - tie hb 3-1/2 x 14 . top flang...
# 240758  1/4 . -20 tpi x 1-1/2 . stainless steel button...
# 240759                      bosch 4 . bi - metal hole saw
#
#                     search_term  relevance  is_train  \
# 0                  angl bracket       3.00         1
# 1                     l bracket       2.50         1
# 2                          deck       3.00         1
# 3              rain shower head       2.33         1
# 4                 shower faucet       2.67         1
# ...                         ...        ...       ...
# 240755  24 whtie storag cabinet        NaN         0
# 240756        adirondeck cusion        NaN         0
# 240757                       hb        NaN         0
# 240758               hex socket        NaN         0
# 240759          4 inch hole saw        NaN         0
#
#                                       product_description  \
# 0       angl make joint stronger also provid consist s...
# 1       angl make joint stronger also provid consist s...
# 2       behr premium textur deckov innov solid color c...
# 3       updat bathroom delta vero singl - handl shower...
# 4       updat bathroom delta vero singl - handl shower...
# ...                                                   ...
# 240755  creat neat yet stylish storag space organ bath...
# 240756  bullnos adirondack chair cushion fit adirondac...
# 240757  joist hanger design provid support underneath ...
# 240758  socket cap screw ideal applic requir well tool...
# 240759  bosch quick chang bi - metal hole saw featur p...
#
#            search_term_transform  \
# 0                  angle bracket
# 1                      l bracket
# 2                           deck
# 3               rain shower head
# 4                  shower faucet
# ...                          ...
# 240755  24 whtie storage cabinet
# 240756         adirondeck cusion
# 240757                        hb
# 240758               hex sockets
# 240759           4 inch hole saw
#
#                                   product_title_transform  \
# 0                    simpson strong - tie 12- gauge angle
# 1                    simpson strong - tie 12- gauge angle
# 2       behr premium textured deck 1- gal . sc -141 tu...
# 3       delta vero 1- handle shower faucet trim kit ch...
# 4       delta vero 1- handle shower faucet trim kit ch...
# ...                                                   ...
# 240755  stufurhome norma 24 . w x 16 . x 34 . h linen ...
# 240756  home decorators collection 49 . alessandro spi...
# 240757  simpson strong - tie hb 3-1/2 x 14 . top flang...
# 240758  1/4 . -20 tpi x 1-1/2 . stainless steel button...
# 240759                      bosch 4 . bi - metal hole saw
#
#                                             pro_des_trans
# 0       angles make joints stronger also provide consi...
# 1       angles make joints stronger also provide consi...
# 2       behr premium textured deckover innovative soli...
# 3       update bathroom delta vero single - handle sho...
# 4       update bathroom delta vero single - handle sho...
# ...                                                   ...
# 240755  create neat yet stylish storage space organizi...
# 240756  bullnose adirondack chair cushions fit adirond...
# 240757  joist hangers designed provide support underne...
# 240758  socket cap screws ideal applications require w...
# 240759  bosch quick change bi - metal hole saws featur...
#
# [240760 rows x 10 columns]

# %%
from nltk.corpus import stopwords 
dic_stopwords = dict(zip(stopwords.words('english'),range(len(stopwords.words('english')))))

# %%
from nltk import SnowballStemmer  
from nltk.corpus import stopwords
import re
import Levenshtein
stemmer = SnowballStemmer('english')

pattern_replace_pair_list = [
            (r"<.+?>", r""),
            # html codes
            (r"&nbsp;", r" "),
            (r"&amp;", r"&"),
            (r"&#39;", r"'"),
            (r"/>/Agt/>", r""),
            (r"</a<gt/", r""),
            (r"gt/>", r""),
            (r"/>", r""),
            (r"<br", r""),
            # do not remove [".", "/", "-", "%"] as they are useful in numbers, e.g., 1.97, 1-1/2, 10%, etc.
            (r"[ &<>)(_,;:!?\+^~@#\$\*]+", r" "),
            (r"'s\\b", r""),
            (r"[']+", r""),
    # 将DeckOver这样次分开，字母与字符英文连在一起的也分开
            #(r'([A-Z][a-z]+|[a-z]+|\d+)', r'\1 '),
            (r'(\d?)([a-zA-Z]+)', r'\1 \2 '),
            #(r'(/d+)', r' \1 '),
            (r'([A-Z][a-z]+)', r' \1 '),
        ]
dic = {1:'one', 2:'two', 3:'three', 4:'four', 5:'five',6:'six', 7:'seven', 8:'eight', 9:'night',0:'zero'}
def dashrep(matchobj):
    if len(matchobj.group())==1:
        return dic[int(matchobj.group())]
    else:
        return matchobj.group() 

# 小写 去除标点符号，停用词
def transform(text):
    for pattern, replace in pattern_replace_pair_list:
        try:
            text = re.sub(pattern, replace, text)
        except:
            pass
    #text = re.sub(r'[\d]+', dashrep, text)
    text = re.sub(r"\s+", " ", text).strip()
    return ' '.join([word for word in text.lower().split() if word not in dic_stopwords])

#word_list = "Package stopwords is already up-to-date".split(" ")
#filtered_words = [word for word in word_list if word not in stopwords.words('english')]

# %%
#关键字的长度
df_all['len_of_query'] = df_all['search_term'].map(lambda x: len(x.split())).astype(np.int64)
#搜索词与标题中有多少关键字重合
df_all['commons_in_title'] = df_all.apply(lambda x:str_common_word(x['search_term'], x['product_title']), axis=1)
#搜索词与描述中有多少关键字重合
#df_all['commons_in_desc'] = df_all.apply(lambda x: str_common_word(x['search_term'], x['product_description'], axis = 1)
df_all['commons_in_desc'] = df_all.apply(lambda x: str_common_word(x['search_term'], x['product_description']), axis=1)

# %%
df_all = df_all.drop(['search_term_transform','product_title_transform','pro_des_trans'],axis=1)

# %%
df_all
# Out:
#             id  product_uid  \
# 0            2       100001
# 1            3       100001
# 2            9       100002
# 3           16       100005
# 4           17       100005
# ...        ...          ...
# 240755  240756       224424
# 240756  240757       224425
# 240757  240758       224426
# 240758  240759       224427
# 240759  240760       224428
#
#                                             product_title  \
# 0                      simpson strong - tie 12- gaug angl
# 1                      simpson strong - tie 12- gaug angl
# 2       behr premium textur deck 1- gal . sc -141 tugb...
# 3       delta vero 1- handl shower faucet trim kit chr...
# 4       delta vero 1- handl shower faucet trim kit chr...
# ...                                                   ...
# 240755  stufurhom norma 24 . w x 16 . x 34 . h linen s...
# 240756  home decor collect 49 . alessandro spiceberri ...
# 240757  simpson strong - tie hb 3-1/2 x 14 . top flang...
# 240758  1/4 . -20 tpi x 1-1/2 . stainless steel button...
# 240759                      bosch 4 . bi - metal hole saw
#
#                     search_term  relevance  is_train  \
# 0                  angl bracket       3.00         1
# 1                     l bracket       2.50         1
# 2                          deck       3.00         1
# 3              rain shower head       2.33         1
# 4                 shower faucet       2.67         1
# ...                         ...        ...       ...
# 240755  24 whtie storag cabinet        NaN         0
# 240756        adirondeck cusion        NaN         0
# 240757                       hb        NaN         0
# 240758               hex socket        NaN         0
# 240759          4 inch hole saw        NaN         0
#
#                                       product_description  len_of_query  \
# 0       angl make joint stronger also provid consist s...             2
# 1       angl make joint stronger also provid consist s...             2
# 2       behr premium textur deckov innov solid color c...             1
# 3       updat bathroom delta vero singl - handl shower...             3
# 4       updat bathroom delta vero singl - handl shower...             2
# ...                                                   ...           ...
# 240755  creat neat yet stylish storag space organ bath...             4
# 240756  bullnos adirondack chair cushion fit adirondac...             2
# 240757  joist hanger design provid support underneath ...             1
# 240758  socket cap screw ideal applic requir well tool...             2
# 240759  bosch quick chang bi - metal hole saw featur p...             4
#
#         commons_in_title  commons_in_desc
# 0                      1                1
# 1                      1                1
# 2                      1                1
# 3                      1                1
# 4                      2                2
# ...                  ...              ...
# 240755                 3                3
# 240756                 0                0
# 240757                 1                1
# 240758                 2                2
# 240759                 3                2
#
# [240760 rows x 10 columns]

# %%
#Levenshtein文本相似度
import Levenshtein
df_all['dist_in_title']=df_all.apply(lambda x:Levenshtein.ratio(x['search_term'],x['product_title']),axis=1)
df_all['dist_in_desc']=df_all.apply(lambda x:Levenshtein.ratio(x['search_term'],x['product_description']),axis=1)

# %%
df_all
# Out:
#             id  product_uid  \
# 0            2       100001
# 1            3       100001
# 2            9       100002
# 3           16       100005
# 4           17       100005
# ...        ...          ...
# 240755  240756       224424
# 240756  240757       224425
# 240757  240758       224426
# 240758  240759       224427
# 240759  240760       224428
#
#                                             product_title  \
# 0                      simpson strong - tie 12- gaug angl
# 1                      simpson strong - tie 12- gaug angl
# 2       behr premium textur deck 1- gal . sc -141 tugb...
# 3       delta vero 1- handl shower faucet trim kit chr...
# 4       delta vero 1- handl shower faucet trim kit chr...
# ...                                                   ...
# 240755  stufurhom norma 24 . w x 16 . x 34 . h linen s...
# 240756  home decor collect 49 . alessandro spiceberri ...
# 240757  simpson strong - tie hb 3-1/2 x 14 . top flang...
# 240758  1/4 . -20 tpi x 1-1/2 . stainless steel button...
# 240759                      bosch 4 . bi - metal hole saw
#
#                     search_term  relevance  is_train  \
# 0                  angl bracket       3.00         1
# 1                     l bracket       2.50         1
# 2                          deck       3.00         1
# 3              rain shower head       2.33         1
# 4                 shower faucet       2.67         1
# ...                         ...        ...       ...
# 240755  24 whtie storag cabinet        NaN         0
# 240756        adirondeck cusion        NaN         0
# 240757                       hb        NaN         0
# 240758               hex socket        NaN         0
# 240759          4 inch hole saw        NaN         0
#
#                                       product_description  len_of_query  \
# 0       angl make joint stronger also provid consist s...             2
# 1       angl make joint stronger also provid consist s...             2
# 2       behr premium textur deckov innov solid color c...             1
# 3       updat bathroom delta vero singl - handl shower...             3
# 4       updat bathroom delta vero singl - handl shower...             2
# ...                                                   ...           ...
# 240755  creat neat yet stylish storag space organ bath...             4
# 240756  bullnos adirondack chair cushion fit adirondac...             2
# 240757  joist hanger design provid support underneath ...             1
# 240758  socket cap screw ideal applic requir well tool...             2
# 240759  bosch quick chang bi - metal hole saw featur p...             4
#
#         commons_in_title  commons_in_desc  dist_in_title  dist_in_desc
# 0                      1                1       0.173913      0.039539
# 1                      1                1       0.139535      0.029801
# 2                      1                1       0.112676      0.010323
# 3                      1                1       0.389610      0.064257
# 4                      2                2       0.351351      0.052525
# ...                  ...              ...            ...           ...
# 240755                 3                3       0.468085      0.076795
# 240756                 0                0       0.268908      0.056478
# 240757                 1                1       0.063492      0.009732
# 240758                 2                2       0.196078      0.043860
# 240759                 3                2       0.545455      0.065421
#
# [240760 rows x 12 columns]

# %%
#删除相关特征
df_all=df_all.drop(['search_term','product_title','product_description'],axis=1)
#重塑训练/测试集
df_train=df_all.loc[df_all['is_train']==1]
df_test=df_all.loc[df_all['is_train']==0]

#记录下测试集的id
test_ids=df_test['id']
#分离出y_train
y_train=df_train['relevance'].values
#把原集中的label删去
X_train=df_train.drop(['id','relevance','is_train'],axis=1).values
X_test=df_test.drop(['id','relevance','is_train'],axis=1).values

# %%
#建立模型
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

params=[1,3,5,6,7,8,9,10]
test_scores=[]
for param in params:
    clf=RandomForestRegressor(n_estimators=30,max_depth=param)
    test_score=np.sqrt(-cross_val_score(clf,X_train,y_train,cv=5,scoring='neg_mean_squared_error'))
    test_scores.append(np.mean(test_score))

import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(params,test_scores)
plt.title('Adjusting parameters')
# Out:
# Text(0.5,1,'Adjusting parameters')

# %%
rf=RandomForestRegressor(n_estimators=30,max_depth=7)
rf.fit(X_train,y_train)
y_pred=rf.predict(X_test)
pd.DataFrame({'id':test_ids,'relevance':y_pred}).to_csv('submissionm.csv',index=False)
